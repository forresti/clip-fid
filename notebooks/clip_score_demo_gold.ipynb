# %%
import json
import os

generated_dir = '../results/2023-01-25_14.40.38.728069'
coco_dir = '../coco'

with open(os.path.join(generated_dir, 'generated.json')) as f:
    generated_pointers = json.load(f)

# %%
generated_pointers[0:20]
# Out:
# [{'image_id': 203564,
#   'caption': 'A bicycle replica with a clock as the front wheel.',
#   'generated_image': '203564_a-bicycle-replica-with-a-clock-as-the-front-wheel.jpg'},
#  {'image_id': 179765,
#   'caption': 'A black Honda motorcycle parked in front of a garage.',
#   'generated_image': '179765_a-black-honda-motorcycle-parked-in-front-of-a-garage.jpg'},
#  {'image_id': 322141,
#   'caption': 'A room with blue walls and a white sink and door.',
#   'generated_image': '322141_a-room-with-blue-walls-and-a-white-sink-and-door.jpg'},
#  {'image_id': 16977,
#   'caption': 'A car that seems to be parked illegally behind a legally parked car',
#   'generated_image': '16977_a-car-that-seems-to-be-parked-illegally-behind-a-legally-parked-car.jpg'},
#  {'image_id': 106140,
#   'caption': 'A large passenger airplane flying through the air.',
#   'generated_image': '106140_a-large-passenger-airplane-flying-through-the-air.jpg'},
#  {'image_id': 106140,
#   'caption': 'There is a GOL plane taking off in a partly cloudy sky.',
#   'generated_image': '106140_there-is-a-gol-plane-taking-off-in-a-partly-cloudy-sky.jpg'},
#  {'image_id': 322141,
#   'caption': 'Blue and white color scheme in a small bathroom.',
#   'generated_image': '322141_blue-and-white-color-scheme-in-a-small-bathroom.jpg'},
#  {'image_id': 322141,
#   'caption': 'This is a blue and white bathroom with a wall sink and a lifesaver on the wall.',
#   'generated_image': '322141_this-is-a-blue-and-white-bathroom-with-a-wall-sink-and-a-lifesaver-on-the-wall.jpg'},
#  {'image_id': 322141,
#   'caption': 'A blue boat themed bathroom with a life preserver on the wall',
#   'generated_image': '322141_a-blue-boat-themed-bathroom-with-a-life-preserver-on-the-wall.jpg'},
#  {'image_id': 203564,
#   'caption': 'The bike has a clock as a tire.',
#   'generated_image': '203564_the-bike-has-a-clock-as-a-tire.jpg'},
#  {'image_id': 179765,
#   'caption': 'A Honda motorcycle parked in a grass driveway',
#   'generated_image': '179765_a-honda-motorcycle-parked-in-a-grass-driveway.jpg'},
#  {'image_id': 16977,
#   'caption': 'two cars parked on the sidewalk on the street',
#   'generated_image': '16977_two-cars-parked-on-the-sidewalk-on-the-street.jpg'},
#  {'image_id': 106140,
#   'caption': 'An airplane that is, either, landing or just taking off.',
#   'generated_image': '106140_an-airplane-that-is-either-landing-or-just-taking-off.jpg'},
#  {'image_id': 322141,
#   'caption': 'A bathroom with walls that are painted baby blue.',
#   'generated_image': '322141_a-bathroom-with-walls-that-are-painted-baby-blue.jpg'},
#  {'image_id': 571635,
#   'caption': 'A bathroom with a toilet, sink, and shower.',
#   'generated_image': '571635_a-bathroom-with-a-toilet-sink-and-shower.jpg'},
#  {'image_id': 301837,
#   'caption': 'A long empty, minimal modern skylit home kitchen.',
#   'generated_image': '301837_a-long-empty-minimal-modern-skylit-home-kitchen.jpg'},
#  {'image_id': 190236,
#   'caption': 'An office cubicle with four different types of computers.',
#   'generated_image': '190236_an-office-cubicle-with-four-different-types-of-computers.jpg'},
#  {'image_id': 315702,
#   'caption': 'A bathroom sink with toiletries on the counter.',
#   'generated_image': '315702_a-bathroom-sink-with-toiletries-on-the-counter.jpg'},
#  {'image_id': 331352,
#   'caption': 'A small closed toilet in a cramped space.',
#   'generated_image': '331352_a-small-closed-toilet-in-a-cramped-space.jpg'},
#  {'image_id': 517069,
#   'caption': 'Two women waiting at a bench next to a street.',
#   'generated_image': '517069_two-women-waiting-at-a-bench-next-to-a-street.jpg'}]

# %%
"""
CLIP-score doesn't actually need the real image; I am just testing that we are able to locate it.
We will need this for FID-score.
"""

def get_real_image_path(coco_dir, image_id):
    image_id_str = str(image_id).zfill(12) # pad to 12 characters
    image_base_fname = f"COCO_val2014_{image_id_str}.jpg"
    image_path = os.path.join(coco_dir, 'val2014', image_base_fname)
    return image_path

real_image_path = get_real_image_path(coco_dir, generated_pointers[0]['image_id'])

real_image_path
# Out:
# '../coco/val2014/COCO_val2014_000000203564.jpg'

# %%
# CLIP score demo

import torch
from torchvision.io import read_image
import torchvision.transforms as T
from torchmetrics.multimodal import CLIPScore
device = torch.device('cuda') 

metric = CLIPScore(model_name_or_path="openai/clip-vit-large-patch14")

for i in range(len(generated_pointers)):
    generated_image_path = os.path.join(generated_dir, generated_pointers[i]['generated_image'])
    generated_image = read_image(generated_image_path)

    # img = T.ToPILImage()(generated_image)
    # img.show()

    metric.update(generated_image, generated_pointers[i]['caption'])

    if i%100 == 0:
        print(f"starting {i}")
# Out:
# starting 0
# starting 100
# starting 200
# starting 300
# starting 400
# starting 500
# starting 600
# starting 700
# starting 800
# starting 900
# starting 1000
# starting 1100
# starting 1200
# starting 1300
# starting 1400
# starting 1500
# starting 1600
# starting 1700
# starting 1800
# starting 1900
# starting 2000
# starting 2100
# starting 2200
# starting 2300
# starting 2400
# starting 2500
# starting 2600
# starting 2700
# starting 2800
# starting 2900
# starting 3000
# starting 3100
# starting 3200
# starting 3300
# starting 3400
# starting 3500
# starting 3600
# starting 3700
# starting 3800
# starting 3900
# starting 4000
# starting 4100
# starting 4200
# starting 4300
# starting 4400
# starting 4500
# starting 4600
# starting 4700
# starting 4800
# starting 4900
# starting 5000
# starting 5100
# starting 5200
# starting 5300
# starting 5400
# starting 5500
# starting 5600
# starting 5700
# starting 5800
# starting 5900
# starting 6000
# starting 6100
# starting 6200
# starting 6300
# starting 6400
# starting 6500
# starting 6600
# starting 6700
# starting 6800
# starting 6900
# starting 7000
# starting 7100
# starting 7200
# starting 7300
# starting 7400
# starting 7500
# starting 7600
# starting 7700
# starting 7800
# starting 7900
# starting 8000
# starting 8100
# starting 8200
# starting 8300
# starting 8400
# starting 8500
# starting 8600
# starting 8700
# starting 8800
# starting 8900
# starting 9000
# starting 9100
# starting 9200
# starting 9300
# starting 9400
# starting 9500
# starting 9600
# starting 9700
# starting 9800
# starting 9900
# starting 10000
# starting 10100
# starting 10200
# starting 10300
# starting 10400
# starting 10500
# starting 10600
# starting 10700
# starting 10800
# starting 10900
# starting 11000
# starting 11100
# starting 11200
# starting 11300
# starting 11400
# starting 11500
# starting 11600
# starting 11700
# starting 11800
# starting 11900
# starting 12000
# starting 12100
# starting 12200
# starting 12300
# starting 12400
# starting 12500
# starting 12600
# starting 12700
# starting 12800
# starting 12900
# starting 13000
# starting 13100
# starting 13200
# starting 13300
# starting 13400
# starting 13500
# starting 13600
# starting 13700
# starting 13800
# starting 13900
# starting 14000
# starting 14100
# starting 14200
# starting 14300
# starting 14400
# starting 14500
# starting 14600
# starting 14700
# starting 14800
# starting 14900
# starting 15000
# starting 15100
# starting 15200
# starting 15300
# starting 15400
# starting 15500
# starting 15600
# starting 15700
# starting 15800
# starting 15900
# starting 16000
# starting 16100
# starting 16200
# starting 16300
# starting 16400
# starting 16500
# starting 16600
# starting 16700
# starting 16800
# starting 16900
# starting 17000
# starting 17100
# starting 17200
# starting 17300
# starting 17400
# starting 17500
# starting 17600
# starting 17700
# starting 17800
# starting 17900
# starting 18000
# starting 18100
# starting 18200
# starting 18300
# starting 18400
# starting 18500
# starting 18600
# starting 18700
# starting 18800
# starting 18900
# starting 19000
# starting 19100
# starting 19200
# starting 19300
# starting 19400
# starting 19500
# starting 19600
# starting 19700
# starting 19800
# starting 19900

# %%
metric.compute()
# Out:
# tensor(26.1764)

# %%
def convert_to_3channel(img):
    if img.shape[0] == 1:
        return img.expand(3,*img.shape[1:])

    else:
        return img

# prep for FID score demo

generated_images = []
real_images = []

for i in range(len(generated_pointers)):
    image_path = get_real_image_path(coco_dir, generated_pointers[i]['image_id'])
    # print(image_path)
    real_images.append(convert_to_3channel(read_image(image_path)))


for i in range(len(generated_pointers)):
    image_path = os.path.join(generated_dir, generated_pointers[i]['generated_image'])
    generated_images.append(convert_to_3channel(read_image(image_path)))

# %%
# FID score demo

from torchmetrics.image.fid import FrechetInceptionDistance

fid = FrechetInceptionDistance(feature=2048)

"""
We are running the following with batch size 1. It would likely be faster to use a larger batch size.
But, the real images have various resolutions and aspect ratios.
It's convenient to let torchmetrics take care of resizing the images.
"""

i = 0
for generated, real in zip(generated_images, real_images):
    if i%100 == 0:
        print(f"generated.shape: {generated.shape}")
        # print(f"real.shape: {real.shape}")
        # print(f"fid score iteration {i}")
    
    fid.update(generated.unsqueeze(0), real=False)
    fid.update(real.unsqueeze(0), real=True)
    
    i += 1
    
fid_score = fid.compute()
print(f"fid score: {fid_score}")
# Out:
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 375, 500])
# fid score iteration 300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 442, 640])
# fid score iteration 400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 425, 640])
# fid score iteration 500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 443, 640])
# fid score iteration 600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 361, 640])
# fid score iteration 800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 424, 640])
# fid score iteration 900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 427])
# fid score iteration 1000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 1100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 1200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 1300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 428, 640])
# fid score iteration 1400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 335, 500])
# fid score iteration 1500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 1600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 283, 640])
# fid score iteration 1700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 460, 640])
# fid score iteration 1800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 428, 640])
# fid score iteration 1900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 424, 640])
# fid score iteration 2000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 506, 640])
# fid score iteration 2100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 364, 640])
# fid score iteration 2200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 424])
# fid score iteration 2300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 2400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 2500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 640])
# fid score iteration 2600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 2700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 427])
# fid score iteration 2800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 425, 640])
# fid score iteration 2900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 3000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 3100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 3200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 3300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 500, 375])
# fid score iteration 3400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 3500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 3600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 333, 500])
# fid score iteration 3700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 3800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 3900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 333, 500])
# fid score iteration 4000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 4100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 478, 640])
# fid score iteration 4200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 406, 640])
# fid score iteration 4300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 428, 640])
# fid score iteration 4400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 427])
# fid score iteration 4500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 4600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 425, 640])
# fid score iteration 4700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 4800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 4900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 384, 640])
# fid score iteration 5000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 5100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 5200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 419, 640])
# fid score iteration 5300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 5400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 333, 500])
# fid score iteration 5500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 5600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 5700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 5800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 360, 640])
# fid score iteration 5900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 6000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 576, 640])
# fid score iteration 6100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 6200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 425, 640])
# fid score iteration 6300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 424, 640])
# fid score iteration 6400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 620, 640])
# fid score iteration 6500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 6600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 6700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 6800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 425, 640])
# fid score iteration 6900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 281, 500])
# fid score iteration 7000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 428])
# fid score iteration 7100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 429])
# fid score iteration 7200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 7300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 7400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 478])
# fid score iteration 7500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 7600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 459, 640])
# fid score iteration 7700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 7800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 426, 640])
# fid score iteration 7900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 426, 640])
# fid score iteration 8000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 8100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 425, 640])
# fid score iteration 8200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 8300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 612, 612])
# fid score iteration 8400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 426, 640])
# fid score iteration 8500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 8600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 8700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 459, 640])
# fid score iteration 8800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 427])
# fid score iteration 8900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 396, 640])
# fid score iteration 9000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 429, 640])
# fid score iteration 9100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 612, 612])
# fid score iteration 9200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 9300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 426, 640])
# fid score iteration 9400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 426])
# fid score iteration 9500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 9600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 9700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 9800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 9900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 10000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 333, 500])
# fid score iteration 10100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 10200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 10300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 428, 640])
# fid score iteration 10400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 478, 640])
# fid score iteration 10500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 10600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 10700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 469, 640])
# fid score iteration 10800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 10900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 11000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 428, 640])
# fid score iteration 11100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 425, 640])
# fid score iteration 11200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 425])
# fid score iteration 11300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 11400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 11500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 478, 640])
# fid score iteration 11600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 11700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 11800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 11900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 12000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 12100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 590, 445])
# fid score iteration 12200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 12300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 12400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 12500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 426, 640])
# fid score iteration 12600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 479, 640])
# fid score iteration 12700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 12800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 12900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 429, 640])
# fid score iteration 13000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 13100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 13200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 500, 375])
# fid score iteration 13300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 427])
# fid score iteration 13400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 13500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 13600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 13700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 397, 640])
# fid score iteration 13800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 500, 375])
# fid score iteration 13900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 14000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 14100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 333, 500])
# fid score iteration 14200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 427])
# fid score iteration 14300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 427])
# fid score iteration 14400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 14500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 640])
# fid score iteration 14600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 371, 500])
# fid score iteration 14700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 500, 375])
# fid score iteration 14800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 426])
# fid score iteration 14900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 434, 640])
# fid score iteration 15000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 360, 640])
# fid score iteration 15100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 427])
# fid score iteration 15200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 15300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 15400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 481, 640])
# fid score iteration 15500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 484, 640])
# fid score iteration 15600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 375, 500])
# fid score iteration 15700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 329, 640])
# fid score iteration 15800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 426, 640])
# fid score iteration 15900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 360])
# fid score iteration 16000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 16100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 16200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 428, 640])
# fid score iteration 16300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 16400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 482])
# fid score iteration 16500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 422, 600])
# fid score iteration 16600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 375, 500])
# fid score iteration 16700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 16800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 426])
# fid score iteration 16900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 612, 612])
# fid score iteration 17000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 428, 640])
# fid score iteration 17100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 17200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 484])
# fid score iteration 17300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 17400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 333, 500])
# fid score iteration 17500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 429, 640])
# fid score iteration 17600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 548, 640])
# fid score iteration 17700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 17800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 428, 640])
# fid score iteration 17900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 480])
# fid score iteration 18000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 428, 640])
# fid score iteration 18100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 375, 500])
# fid score iteration 18200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 18300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 18400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 18500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 18600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 640, 426])
# fid score iteration 18700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 18800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 18900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 512, 640])
# fid score iteration 19000
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 333, 500])
# fid score iteration 19100
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 19200
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 334, 500])
# fid score iteration 19300
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 19400
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 425, 640])
# fid score iteration 19500
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 480, 640])
# fid score iteration 19600
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 427, 640])
# fid score iteration 19700
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 333, 500])
# fid score iteration 19800
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 281, 500])
# fid score iteration 19900
# generated.shape: torch.Size([3, 512, 512])
# real.shape: torch.Size([3, 523, 640])
# fid score iteration 20000
# fid score: 22.720224380493164

# %%
import torch
img = torch.zeros((1, 200, 200))
img = img.expand(3,*img.shape[1:])

# %%
img.shape[0]
# Out:
# 3
